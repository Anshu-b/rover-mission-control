# %%
import sounddevice as sd
import numpy as np
import time

DEVICE = 1          # MacBook Pro microphone
SAMPLE_RATE = 48000
WINDOW = 0.1

TRIALS = 10
TRIAL_DURATION = 5

samples_per_trial = int(TRIAL_DURATION / WINDOW)

stream = sd.InputStream(
    samplerate=SAMPLE_RATE,
    channels=1,
    device=DEVICE
)

stream.start()

for trial in range(TRIALS):

    print(f"\nTrial {trial+1}")

    for i in range(samples_per_trial):

        audio, overflow = stream.read(int(WINDOW * SAMPLE_RATE))

        rms = np.sqrt(np.mean(audio**2))
        db = 20 * np.log10(rms + 1e-6)

        print(db)

stream.stop()
stream.close()
# Out:
# ||PaMacCore (AUHAL)|| AUHAL component not found.
# ---------------------------------------------------------------------------
# PortAudioError                            Traceback (most recent call last)
# Cell In[6], line 14
#      10 TRIAL_DURATION = 5
#      12 samples_per_trial = int(TRIAL_DURATION / WINDOW)
# ---> 14 stream = sd.InputStream(
#      15     samplerate=SAMPLE_RATE,
#      16     channels=1,
#      17     device=DEVICE
#      18 )
#      20 stream.start()
#      22 for trial in range(TRIALS):
#
# File ~/miniconda3/lib/python3.12/site-packages/sounddevice.py:1440, in InputStream.__init__(self, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback)
#    1408 def __init__(self, samplerate=None, blocksize=None,
#    1409              device=None, channels=None, dtype=None, latency=None,
#    1410              extra_settings=None, callback=None, finished_callback=None,
#    1411              clip_off=None, dither_off=None, never_drop_input=None,
#    1412              prime_output_buffers_using_stream_callback=None):
#    1413     """PortAudio input stream (using NumPy).
#    1414
#    1415     This has the same methods and attributes as `Stream`, except
#    (...)
#    1438
#    1439     """
# -> 1440     _StreamBase.__init__(self, kind='input', wrap_callback='array',
#    1441                          **_remove_self(locals()))
#
# File ~/miniconda3/lib/python3.12/site-packages/sounddevice.py:909, in _StreamBase.__init__(self, kind, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback, userdata, wrap_callback)
#     907     userdata = _ffi.NULL
#     908 self._ptr = _ffi.new('PaStream**')
# --> 909 _check(_lib.Pa_OpenStream(self._ptr, iparameters, oparameters,
#     910                           samplerate, blocksize, stream_flags,
#     911                           callback_ptr, userdata),
#     912        f'Error opening {self.__class__.__name__}')
#     914 # dereference PaStream** --> PaStream*
#     915 self._ptr = self._ptr[0]
#
# File ~/miniconda3/lib/python3.12/site-packages/sounddevice.py:2802, in _check(err, msg)
#    2800     hosterror_text = _ffi.string(info.errorText).decode()
#    2801     hosterror_info = host_api, info.errorCode, hosterror_text
# -> 2802     raise PortAudioError(errormsg, err, hosterror_info)
#    2804 raise PortAudioError(errormsg, err)
#
# PortAudioError: Error opening InputStream: Unanticipated host error [PaErrorCode -9999]: '' [<host API not found> error 0]

# %%
import sounddevice as sd
print(sd.query_devices())
# Out:
#   0 Ansh’s iPhone (2) Microphone, Core Audio (1 in, 0 out)
# > 1 MacBook Pro Microphone, Core Audio (1 in, 0 out)
# < 2 MacBook Pro Speakers, Core Audio (0 in, 2 out)

# %%
import sounddevice as sd
print(sd.query_devices(1))
# Out:
# {'name': 'MacBook Pro Microphone', 'index': 1, 'hostapi': 0, 'max_input_channels': 1, 'max_output_channels': 0, 'default_low_input_latency': 0.03235416666666667, 'default_low_output_latency': 0.01, 'default_high_input_latency': 0.0416875, 'default_high_output_latency': 0.1, 'default_samplerate': 48000.0}
